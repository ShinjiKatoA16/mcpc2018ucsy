# %% [markdown]
# # MCPC 2018 Problem A: Taxi Driver
#
# Calculate minimum time from start point to target.

# %% [markdown]
# ### Input
#
# - Integer: Number of Test case
#     + Integer: xa, ya, xb, yb   Source and Destination
#     + Integer: n  Number of Traffic Jams
#         * x1, y1, x2, y2, t   n data of Traffic Jams, x1 < x2, y1 < y2
#
# ### Output
#
# for each test case
#
# - Integer: Minimum time from source location to Destination

# %% [markdown]
# ### Sample Input
#
# ```
# 1
# 1 8 17 5
# 4
# 2 3 3 9 45
# 6 2 11 5 14
# 7 7 10 11 20
# 13 1 16 10 15
# ```
#
# ### Sample Output
#
# ```
# 225
# ```

# %% [markdown]
# ### 1st step: Calculate Edge
#
# We can consider that each coodination(x,y) as Vertex(Node) and time to adjacent Vertex as Edge valule(weight). Default Edge value is 10,  the border of Jam area is not included as Jam area.
#
# If the border is include, we can override the value to **t** of jam area like this.
#
# ```
# for (int row=y1; row<=y2; row++) {     // include y1, y2
#     for (int col=x1; col<x2; col++) {  // include x1, exclude x2
#         edge_right[row][col] = t ;
#     }
# }
#
# for (int col=x1; col<=x2; col++) {     // include x1, x2
#     for (int row=y1; row<y2; row++) {  // include y1, exclude y2
#         edge_up[row][col] = t ;
#     }
# }
# ```
#
# But we need to **exclude the boader**, so the code should be something like
#
# ```
# for (int row=y1+1; row<y2; row++) {   // exclude y1, y2
#     for (int col=x1; col<x2; col++) { // include x1, exclude x2
#         edge_right[row][col] = t ;
#     }
# }
#
# for (int col=x1+1; col<x2; col++) {   // exclude x1, x2
#     for (int row=y1; row<y2; row++) { // include y1, exclude y2
#         edge_up[row][col] = t ;
#     }
# }
# ```
#
# Let's confirm.

# %%
# Jam Data
jam1 = (2, 3, 3, 9, 45)
jam2 = (6, 2, 11, 5, 14)
jam3 = (7, 7, 10, 11, 20)
jam4 = (13, 1, 16, 10, 15)

# jams = (jam1, jam2, jam3, jam4)
jams = (jam1, jam2)

# %%
# Include border

id = 1
for jam in jams:
    print('Jam:', id)
    id += 1
    
    x1, y1, x2, y2, t = jam
    print('right direction')
    for row in range(y1, y2+1):   # include y1 and y2
        for col in range(x1, x2): # include x1, exclude x2
            print(col, row, 'to', col+1, row, 'is updated to', t)
            
    print('up direction')
    for col in range(x1, x2+1):   # include x1 and x2
        for row in range(y1, y2): # include y1, exclude y2
            print(col, row, 'to', col, row+1, 'is updated to', t)
# Out:
# Jam: 1
# right direction
# 2 3 to 3 3 is updated to 45
# 2 4 to 3 4 is updated to 45
# 2 5 to 3 5 is updated to 45
# 2 6 to 3 6 is updated to 45
# 2 7 to 3 7 is updated to 45
# 2 8 to 3 8 is updated to 45
# 2 9 to 3 9 is updated to 45
# up direction
# 2 3 to 2 4 is updated to 45
# 2 4 to 2 5 is updated to 45
# 2 5 to 2 6 is updated to 45
# 2 6 to 2 7 is updated to 45
# 2 7 to 2 8 is updated to 45
# 2 8 to 2 9 is updated to 45
# 3 3 to 3 4 is updated to 45
# 3 4 to 3 5 is updated to 45
# 3 5 to 3 6 is updated to 45
# 3 6 to 3 7 is updated to 45
# 3 7 to 3 8 is updated to 45
# 3 8 to 3 9 is updated to 45
# Jam: 2
# right direction
# 6 2 to 7 2 is updated to 14
# 7 2 to 8 2 is updated to 14
# 8 2 to 9 2 is updated to 14
# 9 2 to 10 2 is updated to 14
# 10 2 to 11 2 is updated to 14
# 6 3 to 7 3 is updated to 14
# 7 3 to 8 3 is updated to 14
# 8 3 to 9 3 is updated to 14
# 9 3 to 10 3 is updated to 14
# 10 3 to 11 3 is updated to 14
# 6 4 to 7 4 is updated to 14
# 7 4 to 8 4 is updated to 14
# 8 4 to 9 4 is updated to 14
# 9 4 to 10 4 is updated to 14
# 10 4 to 11 4 is updated to 14
# 6 5 to 7 5 is updated to 14
# 7 5 to 8 5 is updated to 14
# 8 5 to 9 5 is updated to 14
# 9 5 to 10 5 is updated to 14
# 10 5 to 11 5 is updated to 14
# up direction
# 6 2 to 6 3 is updated to 14
# 6 3 to 6 4 is updated to 14
# 6 4 to 6 5 is updated to 14
# 7 2 to 7 3 is updated to 14
# 7 3 to 7 4 is updated to 14
# 7 4 to 7 5 is updated to 14
# 8 2 to 8 3 is updated to 14
# 8 3 to 8 4 is updated to 14
# 8 4 to 8 5 is updated to 14
# 9 2 to 9 3 is updated to 14
# 9 3 to 9 4 is updated to 14
# 9 4 to 9 5 is updated to 14
# 10 2 to 10 3 is updated to 14
# 10 3 to 10 4 is updated to 14
# 10 4 to 10 5 is updated to 14
# 11 2 to 11 3 is updated to 14
# 11 3 to 11 4 is updated to 14
# 11 4 to 11 5 is updated to 14

# %%
# Exclude border

id = 1
for jam in jams:
    print('Jam:', id)
    id += 1
    
    x1, y1, x2, y2, t = jam
    print('right direction')
    for row in range(y1+1, y2):   # exclude y1 and y2
        for col in range(x1, x2): # include x1, exclude x2
            print(col, row, 'to', col+1, row, 'is updated to', t)
            
    print('up direction')
    for col in range(x1+1, x2):   # exclude x1 and x2
        for row in range(y1, y2): # include y1, exclude y2
            print(col, row, 'to', col, row+1, 'is updated to', t)
# Out:
# Jam: 1
# right direction
# 2 4 to 3 4 is updated to 45
# 2 5 to 3 5 is updated to 45
# 2 6 to 3 6 is updated to 45
# 2 7 to 3 7 is updated to 45
# 2 8 to 3 8 is updated to 45
# up direction
# Jam: 2
# right direction
# 6 3 to 7 3 is updated to 14
# 7 3 to 8 3 is updated to 14
# 8 3 to 9 3 is updated to 14
# 9 3 to 10 3 is updated to 14
# 10 3 to 11 3 is updated to 14
# 6 4 to 7 4 is updated to 14
# 7 4 to 8 4 is updated to 14
# 8 4 to 9 4 is updated to 14
# 9 4 to 10 4 is updated to 14
# 10 4 to 11 4 is updated to 14
# up direction
# 7 2 to 7 3 is updated to 14
# 7 3 to 7 4 is updated to 14
# 7 4 to 7 5 is updated to 14
# 8 2 to 8 3 is updated to 14
# 8 3 to 8 4 is updated to 14
# 8 4 to 8 5 is updated to 14
# 9 2 to 9 3 is updated to 14
# 9 3 to 9 4 is updated to 14
# 9 4 to 9 5 is updated to 14
# 10 2 to 10 3 is updated to 14
# 10 3 to 10 4 is updated to 14
# 10 4 to 10 5 is updated to 14

# %% [markdown]
# #### Reverse edge
#
# Because this problem handles un-ordered edge, we have to prepare reverse edges(**Left** and **Down**) as well.

# %% [markdown]
# ### 2nd Step: SSSP (Single Source Shortest Path)
#
# If we prepared Vertex and Edge data, we can apply SSSP algorithm and solve the problem. Typical SSSP algorithms for this problem are Dijkstra and Bellman-ford. In general, Dijkstra is faster. Dijkstra algorithm can be applied **only if there is no negative edge.**

# %% [markdown]
# #### Java Priority queue
#
# If Dijkstra algorithm is to be used, it is recommended to use priority queue (other variation exists). In case of Java, PriorityQueue is available with java.util.PriorityQueue<E>, if the elements in the queue are user defined class objects, the class need to be **Comparable**, and method **compareTo** need to be specified. https://www.geeksforgeeks.org/comparable-vs-comparator-in-java/
#
# Sample code:
#
# ```
# import java.util.PriorityQueue ;
#
# class Main {
#     public static void main(String argv[]) {
#         PriorityQueue<My_Obj> pq = new PriorityQueue<>() ;
#         pq.add(new My_Obj(100,100)) ;
#         pq.add(new My_Obj(10,220)) ;
#         pq.add(new My_Obj(110,30)) ;
#         pq.add(new My_Obj(1000,1000)) ;
#         pq.add(new My_Obj(10,10)) ;
#
#         while (!pq.isEmpty()) {
#             My_Obj my_obj = pq.remove() ;
#             System.out.println(my_obj.a + " " + my_obj.b) ;
#         }
#     }
# }
#
# class My_Obj implements Comparable<My_Obj> {
#     int a, b ;
#     public My_Obj(int a, int b) {
#         this.a = a ;
#         this.b = b ;
#     }
#
#     public int compareTo(My_Obj another) {
#         if (this.b > another.b) return 1 ;
#         else if (this.b < another.b) return -1 ;
#         else {
#             if (this.a > another.a) return 1 ;
#             else if (this.a < another.a) return -1 ;
#             else return 0 ;
#         }
#     }
# ```

# %% [markdown]
# #### Python priority queue
#
# In case of Python, priority queue is supported by **heapq** library. In order to compare user defined class objects, **`__lt__`** (less than) method is to be defined.

# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-

from heapq import heappush, heappop, heapify
from random import randrange

class my_obj():
    def __init__(self, name, x, y):
        self.name = name
        self.area = x*y
        self.x = x
        self.y = y

    def __lt__(self, other):
        return self.area < other.area

    def __repr__(self):  # string shown in print() function
        return '{}: {} = {}*{}'.format(self.name, self.area, self.x, self.y)

pq = list()

print('Push')
for name in ('a', 'b', 'c', 'd', 'e'):
    x = randrange(1, 20)
    y = randrange(1, 20)
    print(name, x, y)
    heappush(pq, my_obj(name, x, y))

print()
print('Priority Queue:', pq)

print()
print('Pop')
while pq:
    obj = heappop(pq)
    print(obj)
# Out:
# Push
# a 8 4
# b 5 19
# c 13 17
# d 13 2
# e 7 19
#
# Priority Queue: [d: 26 = 13*2, a: 32 = 8*4, c: 221 = 13*17, b: 95 = 5*19, e: 133 = 7*19]
#
# Pop
# d: 26 = 13*2
# a: 32 = 8*4
# b: 95 = 5*19
# e: 133 = 7*19
# c: 221 = 13*17

# %% [markdown]
# ### HashMap - Dictionary (Optional)
#
# In this problem, most of the edges may have default value(10). In that case, memory size can be reduced if **HashMap** is used. Java support **HashMap** with java.util.HashMap.
#
# **HashMap** (dictionary) is a data type which has **key** and **data**.
#
# In case of Python, Dictionary is supported as a standard data type. **DefaultDictionary** may be a good choice in some case. **DefaultDictionary** is implemented in **collections** libary.

# %% [markdown]
# ## Java sample code
#
# ```java
# // MCPC 2018 Problem A: Taxi Driver
#
# import java.util.Scanner ;
# import java.util.PriorityQueue ;
# import java.util.HashMap ;
#
# class prob_a {
#
#     static final long INF = 1000000000000000000L ;  // 10**18
#     static final int DEFAULT_EDGE = 10 ;
#
#     static HashMap<String,Integer> init_edge(int min_x, int max_x, int min_y, int max_y, int num_jam, int [][] jams) {
#         // Return edge[x][y][direction], which contains t value of jams
#         HashMap<String,Integer> edge = new HashMap<String,Integer>() ;
#
#         for (int x = min_x; x <= max_x; x++) {
#             String key_down = "down:"+x+":"+min_y ;
#             String key_up = "up:"+x+":"+max_y ;
#             edge.put(key_down, -1) ;
#             edge.put(key_up, -1) ;
#         }
#         for (int y = min_y; y <= max_y; y++) {
#             String key_right = "right:"+max_x+":"+y ;
#             String key_left = "left:"+min_x+":"+y ;
#             edge.put(key_right, -1) ;
#             edge.put(key_left, -1) ;
#         }
#
#         for (int jam=0; jam < num_jam; jam++) {
#             // Horizontal edge: exclude y1, y2
#             for (int y = jams[jam][1]+1; y < jams[jam][3]; y++) {
#                 // include x1, exclude x2
#                 for (int x = jams[jam][0]; x < jams[jam][2]; x++) {
#                     String key_right = "right:"+x+":"+y ;
#                     String key_left = "left:"+(x+1)+":"+y ;
#                     edge.put(key_right, jams[jam][4]) ;
#                     edge.put(key_left, jams[jam][4]) ;
#                 }
#             }
#
#             // Vertical edge: exclude x1, x2
#             for (int x = jams[jam][0]+1; x < jams[jam][2]; x++) {
#                 // include y1, exclude y2
#                 for (int y = jams[jam][1]; y < jams[jam][3]; y++) {
#                     String key_up = "up:"+x+":"+y ;
#                     String key_down = "down:"+x+":"+(y+1) ;
#                     edge.put(key_up, jams[jam][4]) ;
#                     edge.put(key_down, jams[jam][4]) ;
#                 }
#             }
#         }
#
#         return edge ;
#     }
#
#
#     static void update_pq(int add_weight, int x, int y, long weight, PriorityQueue<PQ_obj> pq, long [][]tmp_dist, int min_x, int min_y) {
#         if (add_weight < 0) return ;
#         long new_weight = add_weight + weight ;
#         if (new_weight < tmp_dist[x-min_x][y-min_y]) {
#             pq.add(new PQ_obj(x, y, new_weight)) ;
#             tmp_dist[x-min_x][y-min_y] = new_weight ;
#         }
#     }
#
#     static void eval_node(PQ_obj pq_obj, PriorityQueue<PQ_obj> pq, long [][]distance,
#                 long [][]tmp_dist, HashMap<String,Integer> edges, int min_x, int min_y) {
#
#         distance[pq_obj.x-min_x][pq_obj.y-min_y] = pq_obj.weight ;
#         tmp_dist[pq_obj.x-min_x][pq_obj.y-min_y] = pq_obj.weight ;
#
#         String key_right = "right:"+pq_obj.x+":"+pq_obj.y ;
#         String key_left = "left:"+pq_obj.x+":"+pq_obj.y ;
#         String key_up = "up:"+pq_obj.x+":"+pq_obj.y ;
#         String key_down = "down:"+pq_obj.x+":"+pq_obj.y ;
#         int right = edges.containsKey(key_right)?edges.get(key_right):DEFAULT_EDGE ;
#         int left = edges.containsKey(key_left)?edges.get(key_left):DEFAULT_EDGE ;
#         int up = edges.containsKey(key_up)?edges.get(key_up):DEFAULT_EDGE ;
#         int down = edges.containsKey(key_down)?edges.get(key_down):DEFAULT_EDGE ;
#
#         update_pq(right, pq_obj.x+1, pq_obj.y, pq_obj.weight, pq, tmp_dist, min_x, min_y) ;
#         update_pq(left, pq_obj.x-1, pq_obj.y, pq_obj.weight, pq, tmp_dist, min_x, min_y) ;
#         update_pq(up, pq_obj.x, pq_obj.y+1, pq_obj.weight, pq, tmp_dist, min_x, min_y) ;
#         update_pq(down, pq_obj.x, pq_obj.y-1, pq_obj.weight, pq, tmp_dist, min_x, min_y) ;
#
#     }
#
#
#     static void dijkstra(int src_x, int src_y, int dest_x, int dest_y,
#            int min_x, int max_x, int min_y, int max_y, HashMap<String,Integer> edges) {
#
#         long [][] distance = new long [max_x-min_x+1][max_y-min_y+1] ;
#         long [][] tmp_dist = new long [max_x-min_x+1][max_y-min_y+1] ;
#
#         for (int x = min_x; x <= max_x; x++) {
#             for (int y = min_y; y <= max_y; y++) {
#                 distance[x-min_x][y-min_y] = INF ;
#                 tmp_dist[x-min_x][y-min_y] = INF ;
#             }
#         }
#
#         distance[src_x-min_x][src_y-min_y] = 0 ;
#         tmp_dist[src_x-min_x][src_y-min_y] = 0 ;
#
#         PriorityQueue<PQ_obj> pq = new PriorityQueue<>() ;
#         pq.add(new PQ_obj(src_x, src_y, 0L)) ;
#
#         while (!pq.isEmpty()) {
#             PQ_obj pq_obj = pq.remove() ;
#             if (pq_obj.x == dest_x && pq_obj.y == dest_y) {
#                 System.out.println(pq_obj.weight) ;
#                 return ;
#             }
#             eval_node(pq_obj, pq, distance, tmp_dist, edges, min_x, min_y) ;
#         }
#
#         System.err.println("No path to destination") ;
#         System.out.println(INF) ;
#         return ;
#     }
#
#
#     public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in) ;
#         int num_tc = sc.nextInt() ;
#
#         for (int tc=0; tc<num_tc; tc++) {
#             int src_x = sc.nextInt() ;
#             int src_y = sc.nextInt() ;
#             int dest_x = sc.nextInt() ;
#             int dest_y = sc.nextInt() ;
#
#             int min_x = Math.min(src_x, dest_x) ;
#             int max_x = Math.max(src_x, dest_x) ;
#             int min_y = Math.min(src_y, dest_y) ;
#             int max_y = Math.max(src_y, dest_y) ;
#
#             int num_jam = sc.nextInt() ;
#             int jams[][] = new int [num_jam][5] ;
#
#             for (int jam=0; jam<num_jam; jam++) {
#                 int x1 = sc.nextInt() ;
#                 int y1 = sc.nextInt() ;
#                 int x2 = sc.nextInt() ;
#                 int y2 = sc.nextInt() ;
#                 int t = sc.nextInt() ;
#
#                 jams[jam][0] = x1 ;
#                 jams[jam][1] = y1 ;
#                 jams[jam][2] = x2 ;
#                 jams[jam][3] = y2 ;
#                 jams[jam][4] = t ;
#                 min_x = Math.min(min_x, x1) ;
#                 min_y = Math.min(min_y, y1) ;
#                 max_x = Math.max(max_x, x2) ;
#                 max_y = Math.max(max_y, y2) ;
#             }
#
#
#             HashMap<String,Integer> edges = init_edge(min_x, max_x, min_y, max_y, num_jam, jams) ;
#             dijkstra(src_x, src_y, dest_x, dest_y, min_x, max_x, min_y, max_y, edges) ;
#         }
#     }
# }
#
# class PQ_obj implements Comparable<PQ_obj> {
#     int x, y ;
#     long weight ;
#
#     public PQ_obj(int x, int y, long weight) {
#         this.x = x ;
#         this.y = y ;
#         this.weight = weight ;
#     }
#
#     public int compareTo(PQ_obj other) {
#         if (this.weight > other.weight) return 1 ;
#         else if (this.weight < other.weight) return -1 ;
#         else return 0 ;
#     }
# }
# ```
